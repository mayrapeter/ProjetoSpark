# %%
import csv
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as  pd

# %% [markdown]
# # CLUSTER

# %% [markdown]
# Constrindo a WordCloud para Apple sozinha

# %%
df_apple = pd.read_csv('apple.csv')
apple = {}

# %%
for i,row in df_apple.iterrows():
    apple[df_apple['Palavra'][i]] = df_apple['Relevância'][i]

# %%
wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(apple)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Constrindo a WordCloud para Samsung sozinha

# %%
df_samsung = pd.read_csv('samsung.csv')
samsung = {}
for i,row in df_samsung.iterrows():
    samsung[df_samsung['Palavra'][i]] = df_samsung['Relevância'][i]

# %%
wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(samsung)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Construindo a WordCloud para Apple e Samsung em conjunto

# %%
df_juntas = pd.read_csv('juntas.csv')
juntas = {}
for i,row in df_juntas.iterrows():
    juntas[df_juntas['Palavra'][i]] = df_juntas['Relevância'][i]

# %%
wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(juntas)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Local sem 5 antes e 5 depois

# %%
df_apple = pd.read_csv('applesem5antespeque.csv')
apple = {}
for i,row in df_apple.iterrows():
    apple[df_apple['Palavra'][i]] = df_apple['Relevância'][i]
    wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(apple)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_samsung = pd.read_csv('samsungsem5antespeque.csv')
samsung = {}
for i,row in df_samsung.iterrows():
    samsung[df_samsung['Palavra'][i]] = df_samsung['Relevância'][i]
    wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(samsung)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_juntas = pd.read_csv('juntassem5antespeque.csv')
juntas = {}
for i,row in df_juntas.iterrows():
    juntas[df_juntas['Palavra'][i]] = df_juntas['Relevância'][i]
    wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(juntas)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Locais com 5 antes e 5 depois

# %%
df_apple = pd.read_csv('applepeque.csv')
apple = {}
for i,row in df_apple.iterrows():
    apple[df_apple['Palavra'][i]] = df_apple['Relevância'][i]
    wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(apple)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_samsung = pd.read_csv('samsungpeque.csv')
samsung = {}
for i,row in df_samsung.iterrows():
    samsung[df_samsung['Palavra'][i]] = df_samsung['Relevância'][i]
    wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(samsung)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_juntas = pd.read_csv('juntaspeque.csv')
juntas = {}
for i,row in df_juntas.iterrows():
    juntas[df_juntas['Palavra'][i]] = df_juntas['Relevância'][i]
    wordcloud = WordCloud(background_color="white")
wordcloud.generate_from_frequencies(juntas)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
